# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Show the values of `dataset1.npy`

# %%
DataSet1 = np.load('dataset1_v3.npy')
print('DataSet1.shape = ', DataSet1.shape)

print('DataSet1[0]: \n', DataSet1[0])
print('DataSet1: \n', DataSet1)
# Out:
# DataSet1.shape =  (80, 1000)
# DataSet1[0]:
#  [ 4 29  5  8  4  5  5  4  4  5  0  5  5 44  4  0  9 44  5  0  8  5  8 44
#  29 26 36 44  5  5 33  4  0  5 19  5 30 28 11  5 36  8  5 24  7  4 18 36
#  49  5  5 18 44  5 36  4 14  4  5 49  9 42 43  5  5 28  5  5  5 48  4 14
#   5  5 14 23 16  4  4 44  5  4  4 26  5 21  7  4  5 36  5 49  5  8  4  4
#   4  5  5  5  5  0 15  4 31  5 43 14 16  8  5  5  8  5  5 36  5 43  5 36
#  18  5 44 31 26  5  5 16  1 17 16  5  4 14 43  5  4  5 43  5 44 21  9 36
#  49  5 44 44  5  8  4 34  5  4 14 18 44 16  5 26 44 34 24  1  3  0  8  5
#  44  5  5 49  5 20 41 35 14  5  5  5  4  4  2 23 43 23 16 36  4 44 26 43
#  10 44  4  5  5  5  5 18  4  4 23  5 22  4 14 44  8 44  5 44 44 24 44 18
#   5 36 14  5 44 29  4 36  5  4  4 36  5  4 43 23 42  5  4  4  4  5 23 35
#  16  5 10  8 26  5 44 36 40  5  5 44 44 16 38  5 41  4 44 44  4 16 13  5
#  47  5  4  5  5  5 49 41 20  5  5  5  5 14  1 43 35  4 46  5  5 31 23 39
# ...

# %% [markdown]
# ## Show the dataset1_appended_v1.npz

# %%
res = np.load('dataComputed/dataset1_appended_v1.npz')
requests = res['requests_v1']
print('requests: \n', requests)

print('#####')
for i in range(200):
    print(requests[i+1200])
# Out:
# requests:
#  [[ 4 -1 -1 -1 -1 -1]
#  [29 -1 -1 -1 -1 -1]
#  [ 5 -1 -1 -1 -1 -1]
#  ...
#  [29 19 31 15 29 22]
#  [13 19 31 15 29 22]
#  [14 19 31 15 29 22]]
# #####
# [28 16  8 44  4  5]
# [48 16  8 44  4  5]
# [43 16  8 44  4  5]
# [49 16  8 44  4  5]
# [43 16  8 44  4  5]
# [ 5 16  8 44  4  5]
# [43 16  8 44  4  5]
# [ 0 16  8 44  4  5]
# [12 16  8 44  4  5]
# [47 16  8 44  4  5]
# [ 5 16  8 44  4  5]
# [ 0 16  8 44  4  5]
# [43 16  8 44  4  5]
# [ 7 16  8 44  4  5]
# [ 8 16  8 44  4  5]
# [ 1 16  8 44  4  5]
# [44 16  8 44  4  5]
# [33 16  8 44  4  5]
# [32 16  8 44  4  5]
# [26 16  8 44  4  5]
# [33 16  8 44  4  5]
# [44 16  8 44  4  5]
# [ 0 16  8 44  4  5]
# [28 16  8 44  4  5]
# [11 16  8 44  4  5]
# [ 0 16  8 44  4  5]
# [16 16  8 44  4  5]
# [38 16  8 44  4  5]
# [44 16  8 44  4  5]
# [48 16  8 44  4  5]
# [44 16  8 44  4  5]
# [35 16  8 44  4  5]
# [10 16  8 44  4  5]
# [10 16  8 44  4  5]
# [14 16  8 44  4  5]
# [43 16  8 44  4  5]
# [27 16  8 44  4  5]
# ...
